# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\aceradmin\Desktop\superstoredata.csv')
print('Shape:', df.shape)
df.head()
# Out:
# Shape: (9800, 18)
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08-11-2017  11-11-2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08-11-2017  11-11-2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12-06-2017  16-06-2017    Second Class    DV-13045
# 3       4  US-2016-108966  11-10-2016  18-10-2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11-10-2016  18-10-2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], errors='coerce')
df['Ship Date'] = pd.to_datetime(df['Ship Date'], errors='coerce')
df = df.dropna(subset=['Order Date', 'Ship Date'])

# %%
print('Missing values:\n', df.isnull().sum())
# Out:
# Missing values:
#  Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      4
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# dtype: int64

# %%
df = df.dropna(subset=['Postal Code'])

# %%
print('Missing values:\n', df.isnull().sum())
# Out:
# Missing values:
#  Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# dtype: int64

# %%
  df = df.drop(columns=['Row ID','Country','Customer Name'])

# %%
df.head()
# Out:
#           Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0   CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 1   CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 13  CA-2017-161389 2017-05-12 2017-10-12  Standard Class    IM-15070
# 35  CA-2017-117590 2017-08-12 2017-10-12     First Class    GH-14485
# 36  CA-2017-117590 2017-08-12 2017-10-12     First Class    GH-14485
#
#       Segment        City       State  Postal Code   Region       Product ID  \
# 0    Consumer   Henderson    Kentucky      42420.0    South  FUR-BO-10001798
# 1    Consumer   Henderson    Kentucky      42420.0    South  FUR-CH-10000454
# 13   Consumer     Seattle  Washington      98103.0     West  OFF-BI-10003656
# 35  Corporate  Richardson       Texas      75080.0  Central  TEC-PH-10004977
# 36  Corporate  Richardson       Texas      75080.0  Central  FUR-FU-10003664
#
#            Category Sub-Category  \
# 0         Furniture    Bookcases
# ...

# %%
df['Year'] = df['Order Date'].dt.year
df['Month'] = df['Order Date'].dt.month
df['Month-Year'] = df['Order Date'].dt.to_period('M').astype(str)

# %%
df.to_csv('Cleaned_Superstore.csv', index=False)
print("Cleaned dataset saved as 'Cleaned_Superstore.csv'")
# Out:
# Cleaned dataset saved as 'Cleaned_Superstore.csv'

# %%
df_check = pd.read_csv('Cleaned_Superstore.csv')
print(df_check.head())
# Out:
#          Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0  CA-2017-152156  2017-08-11  2017-11-11    Second Class    CG-12520
# 1  CA-2017-152156  2017-08-11  2017-11-11    Second Class    CG-12520
# 2  CA-2017-161389  2017-05-12  2017-10-12  Standard Class    IM-15070
# 3  CA-2017-117590  2017-08-12  2017-10-12     First Class    GH-14485
# 4  CA-2017-117590  2017-08-12  2017-10-12     First Class    GH-14485
#
#      Segment        City       State  Postal Code   Region       Product ID  \
# 0   Consumer   Henderson    Kentucky      42420.0    South  FUR-BO-10001798
# 1   Consumer   Henderson    Kentucky      42420.0    South  FUR-CH-10000454
# 2   Consumer     Seattle  Washington      98103.0     West  OFF-BI-10003656
# 3  Corporate  Richardson       Texas      75080.0  Central  TEC-PH-10004977
# 4  Corporate  Richardson       Texas      75080.0  Central  FUR-FU-10003664
#
#           Category Sub-Category  \
# 0        Furniture    Bookcases
# ...
